# %%
import pandas as pd

# %%
retainx_df = pd.read_csv("../data/processed/retainx_hr_1000.csv")

assert retainx_df["Employee_ID"].is_unique
assert retainx_df["Employee_ID"].notna().all()
assert retainx_df["Attrition"].isin(["Yes", "No"]).all()
assert retainx_df["Overtime"].isin(["Yes", "No"]).all()

print("Data quality validation passed.")
# Out:
# Data quality validation passed.
